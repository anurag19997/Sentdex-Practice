# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NSE-MARUTI.csv")
df.head(10)
# Out:
#          Date     Open     High      Low     Last    Close  \
# 0  2018-08-17  9243.00  9286.50  9130.00  9149.95  9152.10
# 1  2018-08-16  9124.00  9235.95  9085.00  9202.20  9200.55
# 2  2018-08-14  9079.00  9158.80  9046.25  9135.00  9132.60
# 3  2018-08-13  9119.45  9185.00  9012.20  9107.00  9080.85
# 4  2018-08-10  9150.00  9210.00  9105.00  9119.90  9148.25
# 5  2018-08-09  9239.00  9239.00  9060.00  9146.00  9146.05
# 6  2018-08-08  9449.00  9449.00  9183.05  9210.00  9207.40
# 7  2018-08-07  9316.00  9420.00  9271.00  9409.00  9411.50
# 8  2018-08-06  9247.50  9300.00  9200.00  9287.00  9286.40
# 9  2018-08-03  9150.00  9230.00  9150.00  9195.00  9187.00
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              477538.0         44002.98
# 1              465479.0         42757.42
# 2              344056.0         31355.62
# 3              348201.0         31750.75
# 4              427827.0         39190.31
# 5              651728.0         59496.38
# ...

# %% [markdown]
# ### In the above data the index column was at

# %%
df.set_index('Date', inplace = True)
df.head()
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2018-08-17  9243.00  9286.50  9130.00  9149.95  9152.10              477538.0
# 2018-08-16  9124.00  9235.95  9085.00  9202.20  9200.55              465479.0
# 2018-08-14  9079.00  9158.80  9046.25  9135.00  9132.60              344056.0
# 2018-08-13  9119.45  9185.00  9012.20  9107.00  9080.85              348201.0
# 2018-08-10  9150.00  9210.00  9105.00  9119.90  9148.25              427827.0
#
#             Turnover (Lacs)
# Date
# 2018-08-17         44002.98
# 2018-08-16         42757.42
# 2018-08-14         31355.62
# 2018-08-13         31750.75
# 2018-08-10         39190.31

# %%
df.to_csv("newcsv.csv")
df  = pd.read_csv("newcsv.csv")
df.head()
# Out:
#    Unnamed: 0        Date     Open     High      Low     Last    Close  \
# 0           0  2018-08-17  9243.00  9286.50  9130.00  9149.95  9152.10
# 1           1  2018-08-16  9124.00  9235.95  9085.00  9202.20  9200.55
# 2           2  2018-08-14  9079.00  9158.80  9046.25  9135.00  9132.60
# 3           3  2018-08-13  9119.45  9185.00  9012.20  9107.00  9080.85
# 4           4  2018-08-10  9150.00  9210.00  9105.00  9119.90  9148.25
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              477538.0         44002.98
# 1              465479.0         42757.42
# 2              344056.0         31355.62
# 3              348201.0         31750.75
# 4              427827.0         39190.31

# %%
df  = pd.read_csv("newcsv.csv", index_col = 1)
df.head()
# Out:
#             Unnamed: 0     Open     High      Low     Last    Close  \
# Date
# 2018-08-17           0  9243.00  9286.50  9130.00  9149.95  9152.10
# 2018-08-16           1  9124.00  9235.95  9085.00  9202.20  9200.55
# 2018-08-14           2  9079.00  9158.80  9046.25  9135.00  9132.60
# 2018-08-13           3  9119.45  9185.00  9012.20  9107.00  9080.85
# 2018-08-10           4  9150.00  9210.00  9105.00  9119.90  9148.25
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-08-17              477538.0         44002.98
# 2018-08-16              465479.0         42757.42
# 2018-08-14              344056.0         31355.62
# 2018-08-13              348201.0         31750.75
# 2018-08-10              427827.0         39190.31

# %%
df.columns = ["", 'Opening', '', '', '', 'Closing', '', '']

# %%
df.head()
# Out:
#                Opening                             Closing
# Date
# 2018-08-17  0  9243.00  9286.50  9130.00  9149.95  9152.10  477538.0  44002.98
# 2018-08-16  1  9124.00  9235.95  9085.00  9202.20  9200.55  465479.0  42757.42
# 2018-08-14  2  9079.00  9158.80  9046.25  9135.00  9132.60  344056.0  31355.62
# 2018-08-13  3  9119.45  9185.00  9012.20  9107.00  9080.85  348201.0  31750.75
# 2018-08-10  4  9150.00  9210.00  9105.00  9119.90  9148.25  427827.0  39190.31

# %%
df.to_csv("new_csv2.csv")
df = pd.read_csv("new_csv2.csv")
df.head()
# Out:
#          Date  Unnamed: 1  Opening  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  2018-08-17           0  9243.00     9286.50     9130.00     9149.95
# 1  2018-08-16           1  9124.00     9235.95     9085.00     9202.20
# 2  2018-08-14           2  9079.00     9158.80     9046.25     9135.00
# 3  2018-08-13           3  9119.45     9185.00     9012.20     9107.00
# 4  2018-08-10           4  9150.00     9210.00     9105.00     9119.90
#
#    Closing  Unnamed: 7  Unnamed: 8
# 0  9152.10    477538.0    44002.98
# 1  9200.55    465479.0    42757.42
# 2  9132.60    344056.0    31355.62
# 3  9080.85    348201.0    31750.75
# 4  9148.25    427827.0    39190.31
